# %%
import sys
sys.path.append("..")

from Guidestar_colocalisation.readClasses import DaxRead
import numpy as np
import os
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
from matplotlib_scalebar.scalebar import ScaleBar

# %% [markdown]
# ### Cell line sample

# %%
filepath = '/Volumes/Seagate Backup Plus Drive/1 year RA data/Guidestar files/cells/100uM_data/'

fig,axes = plt.subplots(1,7, figsize=(14,4))

acly_cell = DaxRead(os.path.join(filepath, 'Cy5_00_02.dax')).loadAllFrames()
gpam_cell = DaxRead(os.path.join(filepath, 'Cy5_01_02.dax')).loadAllFrames()
hnf4a_cell = DaxRead(os.path.join(filepath, 'Cy7_00_02.dax')).loadAllFrames()
ube2z_cell = DaxRead(os.path.join(filepath, 'Cy7_01_02.dax')).loadAllFrames()
igf1_cell = DaxRead(os.path.join(filepath, 'Cy5_10_02.dax')).loadAllFrames()
pigr_cell = DaxRead(os.path.join(filepath, 'Cy7_10_02.dax')).loadAllFrames()
cps1_cell = DaxRead(os.path.join(filepath, 'Cy7_11_02.dax')).loadAllFrames()

# axes[0].imshow(acly_cell[0,1100:1500,1100:1500], cmap='gray', vmin=np.percentile(acly_cell[0,1100:1500,1100:1500],1), vmax=np.percentile(acly_cell[0,1100:1500,1100:1500],99.9))
# axes[1].imshow(gpam_cell[0,1100:1500,1100:1500], cmap='gray', vmin=np.percentile(gpam_cell[0,1100:1500,1100:1500],1), vmax=np.percentile(gpam_cell[0,1100:1500,1100:1500],99.9))
# axes[2].imshow(hnf4a_cell[0,1100:1500,1100:1500], cmap='gray', vmin=np.percentile(hnf4a_cell[0,1100:1500,1100:1500],1), vmax=np.percentile(hnf4a_cell[0,1100:1500,1100:1500],99.9))
# axes[3].imshow(ube2z_cell[0,1100:1500,1100:1500], cmap='gray', vmin=np.percentile(ube2z_cell[0,1100:1500,1100:1500],1), vmax=np.percentile(ube2z_cell[0,1100:1500,1100:1500],99.9))
# axes[4].imshow(igf1_cell[0,1100:1500,1100:1500], cmap='gray', vmin=np.percentile(igf1_cell[0,1100:1500,1100:1500],1), vmax=np.percentile(igf1_cell[0,1100:1500,1100:1500],99.9))
# axes[5].imshow(pigr_cell[0,1100:1500,1100:1500], cmap='gray', vmin=np.percentile(pigr_cell[0,1100:1500,1100:1500],1), vmax=np.percentile(pigr_cell[0,1100:1500,1100:1500],99.9))
# axes[6].imshow(cps1_cell[0,1100:1500,1100:1500], cmap='gray', vmin=np.percentile(cps1_cell[0,1100:1500,1100:1500],1), vmax=np.percentile(cps1_cell[0,1100:1500,1100:1500],99.9))

# image_1 = axes[0].imshow(acly_cell[0,1100:1500,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(acly_cell[0,1100:1500,1100:1500],99.9))
# image_2 = axes[1].imshow(gpam_cell[0,1100:1500,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(gpam_cell[0,1100:1500,1100:1500],99.9))
# image_3 = axes[2].imshow(hnf4a_cell[0,1100:1500,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(hnf4a_cell[0,1100:1500,1100:1500],99.9))
# image_4 = axes[3].imshow(ube2z_cell[0,1100:1500,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(ube2z_cell[0,1100:1500,1100:1500],99.9))
# image_5 = axes[4].imshow(igf1_cell[0,1100:1500,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(igf1_cell[0,1100:1500,1100:1500],99.9))
# image_6 = axes[5].imshow(pigr_cell[0,1100:1500,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(pigr_cell[0,1100:1500,1100:1500],99.9))
# image_7 = axes[6].imshow(cps1_cell[0,1100:1500,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(cps1_cell[0,1100:1500,1100:1500],99.9))

image_1 = axes[0].imshow(acly_cell[0,1300:1700,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(acly_cell[0,1300:1700,1100:1500],99.9))
image_2 = axes[1].imshow(gpam_cell[0,1300:1700,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(gpam_cell[0,1300:1700,1100:1500],99.9))
image_3 = axes[2].imshow(hnf4a_cell[0,1300:1700,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(hnf4a_cell[0,1300:1700,1100:1500],99.9))
image_4 = axes[3].imshow(ube2z_cell[0,1300:1700,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(ube2z_cell[0,1300:1700,1100:1500],99.9))
image_5 = axes[4].imshow(igf1_cell[0,1300:1700,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(igf1_cell[0,1300:1700,1100:1500],99.9))
image_6 = axes[5].imshow(pigr_cell[0,1300:1700,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(pigr_cell[0,1300:1700,1100:1500],99.9))
image_7 = axes[6].imshow(cps1_cell[0,1300:1700,1100:1500], cmap='gray', vmin=0, vmax=np.percentile(cps1_cell[0,1300:1700,1100:1500],99.9))

image_list = [image_1, image_2, image_3, image_4, image_5, image_6, image_7]

for i in range(len(axes)):
    divider = make_axes_locatable(axes[i])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    cbar = fig.colorbar(image_list[i], cax=cax, orientation='vertical')
    ticks = list(cbar.get_ticks())
    cbar.set_ticks([ticks[0],ticks[-1]])
    axes[i].set_xticks([])
    axes[i].set_yticks([])
    
scalebar = ScaleBar(122,'nm', box_color=None, box_alpha=0, color='yellow', location='lower right', width_fraction=0.04, length_fraction=0.3)
axes[6].add_artist(scalebar)

axes[0].set_title('acly')
axes[1].set_title('gpam')
axes[2].set_title('hnf4a')
axes[3].set_title('ube2z')
axes[4].set_title('igf1')
axes[5].set_title('pigr')
axes[6].set_title('cps1')

fig.tight_layout()
fig.savefig('/Volumes/Seagate Backup Plus Drive/1 year RA data/suppfigs/cellexamples_suppfig1.svg')

# %% [markdown]
# ### Tissue sample

# %%
filepath = '/Volumes/Seagate Backup Plus Drive/1 year RA data/Guidestar files/tissue/Data_60uM'
fov = '33'
# 9 and 11 also ok

fig,axes = plt.subplots(1,7, figsize=(14,4))

acly_tissue = DaxRead(os.path.join(filepath, 'Cy5_00_'+ fov + '.dax')).loadAllFrames()
gpam_tissue = DaxRead(os.path.join(filepath, 'Cy5_01_'+ fov + '.dax')).loadAllFrames()
hnf4a_tissue = DaxRead(os.path.join(filepath, 'Cy7_00_'+ fov + '.dax')).loadAllFrames()
ube2z_tissue = DaxRead(os.path.join(filepath, 'Cy7_01_'+ fov + '.dax')).loadAllFrames()
igf1_tissue = DaxRead(os.path.join(filepath, 'Cy5_10_'+ fov + '.dax')).loadAllFrames()
pigr_tissue = DaxRead(os.path.join(filepath, 'Cy7_10_'+ fov + '.dax')).loadAllFrames()
cps1_tissue = DaxRead(os.path.join(filepath, 'Cy7_11_'+ fov + '.dax')).loadAllFrames()

image_1 = axes[0].imshow(acly_tissue[0,1050:1450,500:900], cmap='gray', vmin=0, vmax=np.percentile(acly_tissue[0,1050:1450,500:900],99.9))
image_2 = axes[1].imshow(gpam_tissue[0,1050:1450,500:900], cmap='gray', vmin=0, vmax=np.percentile(gpam_tissue[0,1050:1450,500:900],99.9))
image_3 = axes[2].imshow(hnf4a_tissue[0,1050:1450,500:900], cmap='gray', vmin=0, vmax=np.percentile(hnf4a_tissue[0,1050:1450,500:900],99.9))
image_4 = axes[3].imshow(ube2z_tissue[0,1050:1450,500:900], cmap='gray', vmin=0, vmax=np.percentile(ube2z_tissue[0,1050:1450,500:900],99.9))
image_5 = axes[4].imshow(igf1_tissue[0,1050:1450,500:900], cmap='gray', vmin=0, vmax=np.percentile(igf1_tissue[0,1050:1450,500:900],99.9))
image_6 = axes[5].imshow(pigr_tissue[0,1050:1450,500:900], cmap='gray', vmin=0, vmax=np.percentile(pigr_tissue[0,1050:1450,500:900],99.9))
image_7 = axes[6].imshow(cps1_tissue[0,1050:1450,500:900], cmap='gray', vmin=0, vmax=np.percentile(cps1_tissue[0,1050:1450,500:900],99.9))

# image_1 = axes[0].imshow(acly_tissue[0,1050:1450,500:900], cmap='gray', vmin=np.percentile(acly_tissue[0,1050:1450,500:900],0.01), vmax=np.percentile(acly_tissue[0,1050:1450,500:900],99.9))
# image_2 = axes[1].imshow(gpam_tissue[0,1050:1450,500:900], cmap='gray', vmin=np.percentile(gpam_tissue[0,1050:1450,500:900],0.01), vmax=np.percentile(gpam_tissue[0,1050:1450,500:900],99.9))
# image_3 = axes[2].imshow(hnf4a_tissue[0,1050:1450,500:900], cmap='gray', vmin=np.percentile(hnf4a_tissue[0,1050:1450,500:900],0.01), vmax=np.percentile(hnf4a_tissue[0,1050:1450,500:900],99.9))
# image_4 = axes[3].imshow(ube2z_tissue[0,1050:1450,500:900], cmap='gray', vmin=np.percentile(ube2z_tissue[0,1050:1450,500:900],0.01), vmax=np.percentile(ube2z_tissue[0,1050:1450,500:900],99.9))
# image_5 = axes[4].imshow(igf1_tissue[0,1050:1450,500:900], cmap='gray', vmin=np.percentile(igf1_tissue[0,1050:1450,500:900],0.01), vmax=np.percentile(igf1_tissue[0,1050:1450,500:900],99.9))
# image_6 = axes[5].imshow(pigr_tissue[0,1050:1450,500:900], cmap='gray', vmin=np.percentile(pigr_tissue[0,1050:1450,500:900],0.01), vmax=np.percentile(pigr_tissue[0,1050:1450,500:900],99.9))
# image_7 = axes[6].imshow(cps1_tissue[0,1050:1450,500:900], cmap='gray', vmin=np.percentile(cps1_tissue[0,1050:1450,500:900],0.01), vmax=np.percentile(cps1_tissue[0,1050:1450,500:900],99.9))

axes[0].set_title('acly')
axes[1].set_title('gpam')
axes[2].set_title('hnf4a')
axes[3].set_title('ube2z')
axes[4].set_title('igf1')
axes[5].set_title('pigr')
axes[6].set_title('cps1')

image_list = [image_1, image_2, image_3, image_4, image_5, image_6, image_7]

for i in range(len(axes)):
    divider = make_axes_locatable(axes[i])
    cax = divider.append_axes('right', size='5%', pad=0.05)
    cbar = fig.colorbar(image_list[i], cax=cax, orientation='vertical')
    ticks = list(cbar.get_ticks())
    cbar.set_ticks([ticks[0],ticks[-1]])
    axes[i].set_xticks([])
    axes[i].set_yticks([])
    
scalebar = ScaleBar(122,'nm', box_color=None, box_alpha=0, color='yellow', location='lower right', width_fraction=0.04, length_fraction=0.3)
axes[6].add_artist(scalebar)

fig.tight_layout()
# fig.savefig('/Volumes/Seagate Backup Plus Drive/1 year RA data/suppfigs/tissueexamples_suppfig1_fov13.svg')
